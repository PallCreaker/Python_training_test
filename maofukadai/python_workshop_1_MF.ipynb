# %%
1+1
# Out:
# 2

# %%
1+1
# Out:
# 2

# %%
pip install pandas
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install pandas
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more informations on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
import pandas as pd

# %%
df =  pd.read_csv('C:/Users/170715/Downloads/NHANES_sample_data.csv')

# %%
#問題1
df
# Out:
#           SEQN      RIDAGEYR  RIAGENDR  RIDRETH3       WTINT2YR      WTMEC2YR  \
# 0      73557.0  6.900000e+01       1.0       4.0   13281.237386  1.348104e+04
# 1      73558.0  5.400000e+01       1.0       3.0   23682.057386  2.447177e+04
# 2      73559.0  7.200000e+01       1.0       3.0   57214.803319  5.719329e+04
# 3      73560.0  9.000000e+00       1.0       3.0   55201.178592  5.576651e+04
# 4      73561.0  7.300000e+01       2.0       3.0   63709.667069  6.554187e+04
# 5      73562.0  5.600000e+01       1.0       1.0   24978.144602  2.534499e+04
# 6      73563.0  5.397605e-79       1.0       3.0   18040.818432  1.791356e+04
# 7      73564.0  6.100000e+01       2.0       3.0   60325.095254  6.175865e+04
# 8      73565.0  4.200000e+01       1.0       2.0   23307.675629  5.397605e-79
# 9      73566.0  5.600000e+01       2.0       3.0   16351.783140  1.748012e+04
# 10     73567.0  6.500000e+01       1.0       3.0   34002.622995  3.479543e+04
# ...

# %%
deletedata = df[['RIDRETH3',
'WTINT2YR',
'WTMEC2YR',
'DR1TCARB',
'DR1TTFAT',
'LBXGLU',
'BMXHT']]

# %%
deletedata
# Out:
#        RIDRETH3       WTINT2YR      WTMEC2YR  DR1TCARB  DR1TTFAT  LBXGLU  \
# 0           4.0   13281.237386  1.348104e+04    239.59     52.81     NaN
# 1           3.0   23682.057386  2.447177e+04    423.78    124.29     NaN
# 2           3.0   57214.803319  5.719329e+04    224.39     65.97   193.0
# 3           3.0   55201.178592  5.576651e+04    162.92     58.27     NaN
# 4           3.0   63709.667069  6.554187e+04    178.20     55.36   107.0
# 5           1.0   24978.144602  2.534499e+04    189.59     93.92     NaN
# 6           3.0   18040.818432  1.791356e+04       NaN       NaN     NaN
# 7           3.0   60325.095254  6.175865e+04    300.16     91.03   110.0
# 8           2.0   23307.675629  5.397605e-79       NaN       NaN     NaN
# 9           3.0   16351.783140  1.748012e+04    226.32     41.31     NaN
# 10          3.0   34002.622995  3.479543e+04    216.59     82.95     NaN
# 11          3.0   89514.433218  9.152352e+04    227.63    172.21    89.0
# ...

# %%
deletecol = ['RIDRETH3',
'WTINT2YR',
'WTMEC2YR',
'DR1TCARB',
'DR1TTFAT',
'LBXGLU',
'BMXHT']

# %%
import numpy as np

# %%
DeletedData = df.drop(deletecol, axis=1)

# %%
DeletedData.columns
# Out:
# Index(['SEQN', 'RIDAGEYR', 'RIAGENDR', 'BMXWT', 'BMXBMI', 'LBXGH', 'LBDGLUSI'], dtype='object')

# %%
DeletedData.rename(columns={'RIDAGEYR': 'Age'}, 
                   {'RIAGENDR': 'Gender'},
                   inplace=True)
# Out:
#   File "<ipython-input-13-d7299dfdb9f9>", line 2
#     {'RIAGENDR': 'Gender'},
#     ^
# SyntaxError: positional argument follows keyword argument

# %%
DeletedData.rename(columns={'RIDAGEYR': 'Age','RIAGENDR': 'Gender','BMXWT':'Body_weight',
'BMXBMI':'BMI',
'LBXGH':'HbA1c',
'LBDGLUSI':'Glucose'
},inplace=True)

# %%
DeletedData.columns
# Out:
# Index(['SEQN', 'Age', 'Gender', 'Body_weight', 'BMI', 'HbA1c', 'Glucose'], dtype='object')

# %%
df2 = DeletedData.dropna(how='any')

# %%
length(DeletedData)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-bfa52aafd7bc> in <module>()
# ----> 1 length(DeletedData)
#
# NameError: name 'length' is not defined

# %%
DeletedData.shape
# Out:
# (10175, 7)

# %%
df2.shape
# Out:
# (3138, 7)

# %%
df2['Height'] = 0
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2 = df2.DataFrame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-689f2b65ac95> in <module>()
# ----> 1 df2 = df2.DataFrame
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'

# %%
df2 = pd.DataFrame(df2)

# %%
df2['Height'] = 0

# %%
df2
# Out:
#           SEQN   Age  Gender  Body_weight   BMI  HbA1c  Glucose  Height
# 2      73559.0  72.0     1.0         88.9  28.9    8.9   10.713       0
# 4      73561.0  73.0     2.0         52.0  19.7    4.9    5.940       0
# 7      73564.0  61.0     2.0         93.4  35.7    5.5    6.106       0
# 11     73568.0  26.0     2.0         47.1  20.3    5.2    4.940       0
# 17     73574.0  33.0     2.0         56.8  22.8    5.0    4.663       0
# 19     73576.0  16.0     1.0         67.3  23.2    5.1    4.940       0
# 20     73577.0  32.0     1.0         79.7  28.9    5.3    5.773       0
# 23     73580.0  38.0     2.0         93.5  35.9    5.8    5.718       0
# 24     73581.0  50.0     1.0         80.9  23.6    5.0    6.106       0
# 30     73587.0  14.0     1.0        110.2  38.7    5.7    5.218       0
# 39     73596.0  57.0     2.0        104.0  38.3    5.9    5.940       0
# 41     73598.0  20.0     1.0         86.7  31.8    5.2    6.106       0
# ...

# %%
df3 = df2.assign(
    X=df2.apply(lambda x: math.sqrt(x['Body_weight']/x['BMI']), axis=1)
)

# %%
import math

# %%
df3
# Out:
#           SEQN   Age  Gender  Body_weight   BMI  HbA1c  Glucose  Height  \
# 2      73559.0  72.0     1.0         88.9  28.9    8.9   10.713       0
# 4      73561.0  73.0     2.0         52.0  19.7    4.9    5.940       0
# 7      73564.0  61.0     2.0         93.4  35.7    5.5    6.106       0
# 11     73568.0  26.0     2.0         47.1  20.3    5.2    4.940       0
# 17     73574.0  33.0     2.0         56.8  22.8    5.0    4.663       0
# 19     73576.0  16.0     1.0         67.3  23.2    5.1    4.940       0
# 20     73577.0  32.0     1.0         79.7  28.9    5.3    5.773       0
# 23     73580.0  38.0     2.0         93.5  35.9    5.8    5.718       0
# 24     73581.0  50.0     1.0         80.9  23.6    5.0    6.106       0
# 30     73587.0  14.0     1.0        110.2  38.7    5.7    5.218       0
# 39     73596.0  57.0     2.0        104.0  38.3    5.9    5.940       0
# 41     73598.0  20.0     1.0         86.7  31.8    5.2    6.106       0
# ...

# %%
df3 = df2.assign(
    Height=df2.apply(lambda Height: math.sqrt(Height['Body_weight']/Height['BMI']), axis=1)
)

# %%
df3
# Out:
#           SEQN   Age  Gender  Body_weight   BMI  HbA1c  Glucose  Height  \
# 2      73559.0  72.0     1.0         88.9  28.9    8.9   10.713       0
# 4      73561.0  73.0     2.0         52.0  19.7    4.9    5.940       0
# 7      73564.0  61.0     2.0         93.4  35.7    5.5    6.106       0
# 11     73568.0  26.0     2.0         47.1  20.3    5.2    4.940       0
# 17     73574.0  33.0     2.0         56.8  22.8    5.0    4.663       0
# 19     73576.0  16.0     1.0         67.3  23.2    5.1    4.940       0
# 20     73577.0  32.0     1.0         79.7  28.9    5.3    5.773       0
# 23     73580.0  38.0     2.0         93.5  35.9    5.8    5.718       0
# 24     73581.0  50.0     1.0         80.9  23.6    5.0    6.106       0
# 30     73587.0  14.0     1.0        110.2  38.7    5.7    5.218       0
# 39     73596.0  57.0     2.0        104.0  38.3    5.9    5.940       0
# 41     73598.0  20.0     1.0         86.7  31.8    5.2    6.106       0
# ...

# %%
df3
# Out:
#           SEQN   Age  Gender  Body_weight   BMI  HbA1c  Glucose    Height
# 2      73559.0  72.0     1.0         88.9  28.9    8.9   10.713  1.753888
# 4      73561.0  73.0     2.0         52.0  19.7    4.9    5.940  1.624683
# 7      73564.0  61.0     2.0         93.4  35.7    5.5    6.106  1.617482
# 11     73568.0  26.0     2.0         47.1  20.3    5.2    4.940  1.523219
# 17     73574.0  33.0     2.0         56.8  22.8    5.0    4.663  1.578362
# 19     73576.0  16.0     1.0         67.3  23.2    5.1    4.940  1.703192
# 20     73577.0  32.0     1.0         79.7  28.9    5.3    5.773  1.660658
# 23     73580.0  38.0     2.0         93.5  35.9    5.8    5.718  1.613833
# 24     73581.0  50.0     1.0         80.9  23.6    5.0    6.106  1.851477
# 30     73587.0  14.0     1.0        110.2  38.7    5.7    5.218  1.687467
# 39     73596.0  57.0     2.0        104.0  38.3    5.9    5.940  1.647849
# 41     73598.0  20.0     1.0         86.7  31.8    5.2    6.106  1.651186
# ...

# %%
print(np.mean(df3, axis=1))
# Out:
# 2         9221.395861
# 4         9215.020585
# 7         9221.165435
# 11        9209.382902
# 17        9212.480170
# 19        9211.905399
# 20        9216.416707
# 23        9220.316479
# 24        9218.682185
# 30        9220.438183
# 39        9226.348481
# 41        9218.807148
# 43        9227.012731
# 50        9230.679507
# 53        9223.095333
# 61        9224.824781
# 62        9222.180992
# 64        9226.989162
# 76        9224.718604
# 81        9225.324381
# 82        9229.715381
# 83        9224.850515
# 85        9230.839810
# 90        9228.349834
# 98        9232.084743
# 99        9229.977606
# 100       9224.770348
# 102       9238.688807
# 104       9222.926443
# 106       9232.429961
#              ...
# 10071    10474.100782
# 10073    10475.767635
# 10076    10477.229176
# 10080    10489.796658
# 10081    10478.720934
# 10085    10474.709325
# 10089    10475.323380
# 10091    10468.932978
# 10098    10490.995425
# 10101    10478.508740
# ...

# %%
print(np.mean(df3, axis=0))
# Out:
# SEQN           78713.195029
# Age               43.210644
# Gender             1.515934
# Body_weight       78.594519
# BMI               28.142925
# HbA1c              5.640121
# Glucose            5.823680
# Height             1.667282
# dtype: float64

# %%
print(np.median(df3, axis=0))
# Out:
# [7.87355000e+04 4.30000000e+01 2.00000000e+00 7.52000000e+01
#  2.70000000e+01 5.40000000e+00 5.44000000e+00 1.66101801e+00]

# %%
print(np.var(df3, axis=0))
# Out:
# SEQN           8.503421e+06
# Age            4.256596e+02
# Gender         2.497461e-01
# Body_weight    5.215127e+02
# BMI            5.516770e+01
# HbA1c          9.649773e-01
# Glucose        3.039481e+00
# Height         1.018800e-02
# dtype: float64

# %%
print(np.mean(df3, axis=0))
# Out:
# SEQN           78713.195029
# Age               43.210644
# Gender             1.515934
# Body_weight       78.594519
# BMI               28.142925
# HbA1c              5.640121
# Glucose            5.823680
# Height             1.667282
# dtype: float64

# %%
print(np.amax(df3, axis=0))
# Out:
# SEQN           83727.000000
# Age               80.000000
# Gender             2.000000
# Body_weight      201.600000
# BMI               82.900000
# HbA1c             15.400000
# Glucose           23.370000
# Height             1.981885
# dtype: float64

# %%
print(np.amin(df3, axis=0))
# Out:
# SEQN           73559.00000
# Age               12.00000
# Gender             1.00000
# Body_weight       30.10000
# BMI               13.40000
# HbA1c              3.50000
# Glucose            2.83100
# Height             1.36732
# dtype: float64

# %%
print(np.percentile(df3, axis=0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-c1be3734bc1a> in <module>()
# ----> 1 print(np.percentile(df3, axis=0))
#
# TypeError: percentile() missing 1 required positional argument: 'q'

# %%
pd.df3(pd.Series(arr.ravel()).describe()).transpose()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-4cd405062087> in <module>()
# ----> 1 pd.df3(pd.Series(arr.ravel()).describe()).transpose()
#
# AttributeError: module 'pandas' has no attribute 'df3'

# %%
pd.DataFrame(pd.Series(df3.ravel()).describe()).transpose()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-ed6e37a46a9b> in <module>()
# ----> 1 pd.DataFrame(pd.Series(df3.ravel()).describe()).transpose()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ravel'

# %%
import numpy as np
import pandas as pd

# %%
pd.DataFrame(pd.Series(df3.ravel()).describe()).transpose()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-ed6e37a46a9b> in <module>()
# ----> 1 pd.DataFrame(pd.Series(df3.ravel()).describe()).transpose()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ravel'

# %%
print(pd.describe(df3, axis=0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-1f635700a21b> in <module>()
# ----> 1 print(pd.describe(df3, axis=0))
#
# AttributeError: module 'pandas' has no attribute 'describe'

# %%
print(np.std(df3, axis=0))
# Out:
# SEQN           2916.062630
# Age              20.631519
# Gender            0.499746
# Body_weight      22.836653
# BMI               7.427496
# HbA1c             0.982333
# Glucose           1.743411
# Height            0.100936
# dtype: float64

# %%
print(np.percentile(df3, axis=0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-c1be3734bc1a> in <module>()
# ----> 1 print(np.percentile(df3, axis=0))
#
# TypeError: percentile() missing 1 required positional argument: 'q'

# %%
print(np.percentile(75,df3, axis=0))
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-58-76f565435c43> in <module>()
# ----> 1 print(np.percentile(75,df3, axis=0))
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    4289     r, k = _ureduce(a, func=_percentile, q=q, axis=axis, out=out,
#    4290                     overwrite_input=overwrite_input,
# -> 4291                     interpolation=interpolation)
#    4292     if keepdims:
#    4293         return r.reshape(q.shape + k)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    4011         keepdim = list(a.shape)
#    4012         nd = a.ndim
# -> 4013         axis = _nx.normalize_axis_tuple(axis, nd)
#    4014
#    4015         for ax in axis:
#
# ...

# %%
print(df3.describe())
# Out:
#                SEQN          Age       Gender  Body_weight          BMI  \
# count   3138.000000  3138.000000  3138.000000  3138.000000  3138.000000
# mean   78713.195029    43.210644     1.515934    78.594519    28.142925
# std     2916.527378    20.634807     0.499826    22.840293     7.428680
# min    73559.000000    12.000000     1.000000    30.100000    13.400000
# 25%    76200.750000    24.000000     1.000000    62.800000    22.900000
# 50%    78735.500000    43.000000     2.000000    75.200000    27.000000
# 75%    81240.250000    60.000000     2.000000    90.000000    31.600000
# max    83727.000000    80.000000     2.000000   201.600000    82.900000
#
#              HbA1c      Glucose       Height
# count  3138.000000  3138.000000  3138.000000
# mean      5.640121     5.823680     1.667282
# std       0.982489     1.743688     0.100952
# min       3.500000     2.831000     1.367320
# 25%       5.200000     5.051000     1.595248
# 50%       5.400000     5.440000     1.661018
# ...

# %%
test = df3[(df3['Age'] >= 20) & (df3['BMI']>=18.0)& (df3['BMI'] <= 50) &(df3['Glucose']>=4) & (df3['Glucose']<= 16) & (df3['HbA1c']>=4)&(df3['HbAlc']<= 10)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HbAlc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-9296f354a4b1> in <module>()
# ...

# %%
test = df3[df3.index.Age >= 20]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-c04485889ca0> in <module>()
# ----> 1 test = df3[df3.index.Age >= 20]
#
# AttributeError: 'Int64Index' object has no attribute 'Age'

# %%
test = df3[(df3['Age'] >= 20) & 18 <= df3.BMI & df3.BMI <= 50.0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-1e1de7739d31> in <module>()
# ----> 1 test = df3[df3.Age >= 20 & 18 <= df3.BMI & df3.BMI <= 50.0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1119         raise ValueError("The truth value of a {0} is ambiguous. "
#    1120                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1121                          .format(self.__class__.__name__))
#    1122
#    1123     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df_and = df3[(df3['Age'] < 35) & (df3['BMI'] >=18)]

# %%
df3['Gender']
# Out:
# 2        1.0
# 4        2.0
# 7        2.0
# 11       2.0
# 17       2.0
# 19       1.0
# 20       1.0
# 23       2.0
# 24       1.0
# 30       1.0
# 39       2.0
# 41       1.0
# 43       1.0
# 50       1.0
# 53       1.0
# 61       2.0
# 62       2.0
# 64       1.0
# 76       2.0
# 81       2.0
# 82       1.0
# 83       2.0
# 85       2.0
# 90       2.0
# 98       1.0
# 99       1.0
# 100      2.0
# 102      2.0
# 104      1.0
# 106      1.0
#         ...
# 10071    1.0
# 10073    2.0
# 10076    1.0
# 10080    1.0
# 10081    1.0
# 10085    1.0
# 10089    1.0
# 10091    2.0
# 10098    1.0
# 10101    2.0
# 10109    1.0
# 10116    2.0
# 10119    2.0
# 10120    2.0
# 10121    2.0
# 10122    2.0
# 10126    2.0
# 10135    1.0
# 10137    2.0
# 10142    2.0
# 10145    2.0
# 10150    1.0
# 10151    1.0
# 10154    2.0
# 10155    1.0
# 10156    1.0
# 10157    2.0
# 10161    2.0
# 10166    1.0
# 10170    1.0
# Name: Gender, Length: 3138, dtype: float64

# %%
man = df3['Gender'] ==1.0

# %%
woman = df3['Gender'] ==2.0

# %% [markdown]
# print(man.sum())

# %%
man.sum()
# Out:
# 1519

# %%
woman.sum()
# Out:
# 1619

# %% [markdown]
# numpy.percentile(df3['Gender'],75)

# %%
numpy.percentile(df3['Gender'],75)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-523bda4eb5a3> in <module>()
# ----> 1 numpy.percentile(df3['Gender'],75)
#
# NameError: name 'numpy' is not defined

# %%
np.percentile(df3['Age'],75)
# Out:
# 60.0

# %%
 df_lim = df3[(df3['Age'] >= 20) & (df3['BMI'] >=18) &(df3['BMI'] <= 50) & (df3['Glucose']>=4.0) 
     & (df3['Glucose']<= 16.0) & (df3['HbA1c']>=4.0) & (df3['HbA1c']<= 10)]

# %%
A = df3['BMI']

# %%
B = df_lim['Body_weight','Glucose']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Body_weight', 'Glucose')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-935bc28029cd> in <module>()
# ...

# %%
df_lim
# Out:
#           SEQN   Age  Gender  Body_weight   BMI  HbA1c  Glucose    Height
# 2      73559.0  72.0     1.0         88.9  28.9    8.9   10.713  1.753888
# 4      73561.0  73.0     2.0         52.0  19.7    4.9    5.940  1.624683
# 7      73564.0  61.0     2.0         93.4  35.7    5.5    6.106  1.617482
# 11     73568.0  26.0     2.0         47.1  20.3    5.2    4.940  1.523219
# 17     73574.0  33.0     2.0         56.8  22.8    5.0    4.663  1.578362
# 20     73577.0  32.0     1.0         79.7  28.9    5.3    5.773  1.660658
# 23     73580.0  38.0     2.0         93.5  35.9    5.8    5.718  1.613833
# 24     73581.0  50.0     1.0         80.9  23.6    5.0    6.106  1.851477
# 39     73596.0  57.0     2.0        104.0  38.3    5.9    5.940  1.647849
# 41     73598.0  20.0     1.0         86.7  31.8    5.2    6.106  1.651186
# 43     73600.0  37.0     1.0        126.2  36.8    6.2    7.050  1.851850
# 50     73607.0  75.0     1.0        111.9  38.9    5.0    4.940  1.696056
# ...

# %%
B = df_lim.loc[:,['Body_weight','Glucose']]

# %%
A = df_lim['BMI']

# %%
temp = pd.merge(A,B)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-580f3849ff38> in <module>()
# ----> 1 temp = pd.merge(A,B)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      55                          right_index=right_index, sort=sort, suffixes=suffixes,
#      56                          copy=copy, indicator=indicator,
# ---> 57                          validate=validate)
#      58     return op.get_result()
#      59
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     536         if not isinstance(left, DataFrame):
# ...

# %%
temp = pd.concat([A,B], axis=1)

# %%
temp
# Out:
#         BMI  Body_weight  Glucose
# 2      28.9         88.9   10.713
# 4      19.7         52.0    5.940
# 7      35.7         93.4    6.106
# 11     20.3         47.1    4.940
# 17     22.8         56.8    4.663
# 20     28.9         79.7    5.773
# 23     35.9         93.5    5.718
# 24     23.6         80.9    6.106
# 39     38.3        104.0    5.940
# 41     31.8         86.7    6.106
# 43     36.8        126.2    7.050
# 50     38.9        111.9    4.940
# 53     28.9         90.2    4.996
# 61     32.7         79.4    5.440
# 62     27.3         81.7    4.718
# 64     24.6         76.4    5.551
# 76     30.5         76.8    5.662
# 81     24.8         60.9    6.328
# 82     30.3         81.5    7.383
# 83     22.1         54.9    6.328
# 85     37.8         95.5    5.329
# 90     27.7         74.2    6.162
# 98     31.2        113.1    4.774
# 99     28.0         88.8    4.940
# 102    46.1        117.2    7.716
# 104    21.0         63.4    4.774
# ...

# %%
df_lim[,34]
# Out:
#   File "<ipython-input-95-b897f881c55e>", line 1
#     df_lim[,34]
#            ^
# SyntaxError: invalid syntax

# %%
df_lim
# Out:
#           SEQN   Age  Gender  Body_weight   BMI  HbA1c  Glucose    Height
# 2      73559.0  72.0     1.0         88.9  28.9    8.9   10.713  1.753888
# 4      73561.0  73.0     2.0         52.0  19.7    4.9    5.940  1.624683
# 7      73564.0  61.0     2.0         93.4  35.7    5.5    6.106  1.617482
# 11     73568.0  26.0     2.0         47.1  20.3    5.2    4.940  1.523219
# 17     73574.0  33.0     2.0         56.8  22.8    5.0    4.663  1.578362
# 20     73577.0  32.0     1.0         79.7  28.9    5.3    5.773  1.660658
# 23     73580.0  38.0     2.0         93.5  35.9    5.8    5.718  1.613833
# 24     73581.0  50.0     1.0         80.9  23.6    5.0    6.106  1.851477
# 39     73596.0  57.0     2.0        104.0  38.3    5.9    5.940  1.647849
# 41     73598.0  20.0     1.0         86.7  31.8    5.2    6.106  1.651186
# 43     73600.0  37.0     1.0        126.2  36.8    6.2    7.050  1.851850
# 50     73607.0  75.0     1.0        111.9  38.9    5.0    4.940  1.696056
# ...

# %%
df_lim.iloc[34]
# Out:
# SEQN           73690.000000
# Age               77.000000
# Gender             2.000000
# Body_weight       56.300000
# BMI               21.400000
# HbA1c              5.800000
# Glucose            4.996000
# Height             1.621987
# Name: 133, dtype: float64

# %%
c
# Out:
# 2         88.9
# 4         52.0
# 7         93.4
# 11        47.1
# 17        56.8
# 20        79.7
# 23        93.5
# 24        80.9
# 39       104.0
# 41        86.7
# 43       126.2
# 50       111.9
# 53        90.2
# 61        79.4
# 62        81.7
# 64        76.4
# 76        76.8
# 81        60.9
# 82        81.5
# 83        54.9
# 85        95.5
# 90        74.2
# 98       113.1
# 99        88.8
# 102      117.2
# 104       63.4
# 106      124.8
# 110       88.2
# 111       83.1
# 114       58.2
#          ...
# 10055     97.7
# 10056     84.1
# 10058     77.0
# 10059     78.8
# 10061     97.1
# 10062     85.6
# 10068     55.6
# 10070     81.9
# 10073     55.2
# 10076     96.7
# 10080    179.4
# 10081     72.3
# 10085     81.4
# 10089     65.4
# 10098    166.3
# 10101     72.2
# 10119     60.0
# 10121     50.0
# 10126     76.5
# 10135     63.6
# 10137     71.3
# 10142     53.3
# 10145     69.1
# 10151    175.2
# 10154     81.9
# 10155     90.8
# 10156     62.5
# ...

# %%
df_lim.iloc[57,4]
# Out:
# 30.2

# %%
df_lim.iloc[[50,100,250],[1,4]]
# Out:
#        Age   BMI
# 199   56.0  25.6
# 438   40.0  23.5
# 1039  45.0  29.2

# %%
df_lim.iloc[[57],[2,3,5]]
# Out:
#      Gender  Body_weight  HbA1c
# 224     2.0         80.1    5.7

# %%
df_lim.loc[[128,['Body_weight']]
# Out:
#   File "<ipython-input-106-4081b9776a3b>", line 1
#     df_lim.loc[[128,['Body_weight']]
#                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
df_lim.loc['128',['Body_weight']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [128] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-98441a9e6bd7> in <module>()
# ----> 1 df_lim.loc['128',['Body_weight']]
#
# ...

# %%
df_lim
# Out:
#           SEQN   Age  Gender  Body_weight   BMI  HbA1c  Glucose    Height
# 2      73559.0  72.0     1.0         88.9  28.9    8.9   10.713  1.753888
# 4      73561.0  73.0     2.0         52.0  19.7    4.9    5.940  1.624683
# 7      73564.0  61.0     2.0         93.4  35.7    5.5    6.106  1.617482
# 11     73568.0  26.0     2.0         47.1  20.3    5.2    4.940  1.523219
# 17     73574.0  33.0     2.0         56.8  22.8    5.0    4.663  1.578362
# 20     73577.0  32.0     1.0         79.7  28.9    5.3    5.773  1.660658
# 23     73580.0  38.0     2.0         93.5  35.9    5.8    5.718  1.613833
# 24     73581.0  50.0     1.0         80.9  23.6    5.0    6.106  1.851477
# 39     73596.0  57.0     2.0        104.0  38.3    5.9    5.940  1.647849
# 41     73598.0  20.0     1.0         86.7  31.8    5.2    6.106  1.651186
# 43     73600.0  37.0     1.0        126.2  36.8    6.2    7.050  1.851850
# 50     73607.0  75.0     1.0        111.9  38.9    5.0    4.940  1.696056
# ...

# %%
df_lim['Body_weight']
# Out:
# 2         88.9
# 4         52.0
# 7         93.4
# 11        47.1
# 17        56.8
# 20        79.7
# 23        93.5
# 24        80.9
# 39       104.0
# 41        86.7
# 43       126.2
# 50       111.9
# 53        90.2
# 61        79.4
# 62        81.7
# 64        76.4
# 76        76.8
# 81        60.9
# 82        81.5
# 83        54.9
# 85        95.5
# 90        74.2
# 98       113.1
# 99        88.8
# 102      117.2
# 104       63.4
# 106      124.8
# 110       88.2
# 111       83.1
# 114       58.2
#          ...
# 10055     97.7
# 10056     84.1
# 10058     77.0
# 10059     78.8
# 10061     97.1
# 10062     85.6
# 10068     55.6
# 10070     81.9
# 10073     55.2
# 10076     96.7
# 10080    179.4
# 10081     72.3
# 10085     81.4
# 10089     65.4
# 10098    166.3
# 10101     72.2
# 10119     60.0
# 10121     50.0
# 10126     76.5
# 10135     63.6
# 10137     71.3
# 10142     53.3
# 10145     69.1
# 10151    175.2
# 10154     81.9
# 10155     90.8
# 10156     62.5
# ...

# %%
df_lim.ix[[128],['Body_weight']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#      Body_weight
# 128          NaN

# %%
1:3:6
# Out:
#   File "<ipython-input-121-03fad9dbe7b6>", line 1
#     1:3:6
#        ^
# SyntaxError: invalid syntax

# %%
1:6
# Out:
#   File "<ipython-input-122-16b2e23d54cf>", line 1
#     1:6
#        ^
# SyntaxError: illegal target for annotation

# %%
print(1:3)
# Out:
#   File "<ipython-input-123-b875577d2044>", line 1
#     print(1:3)
#            ^
# SyntaxError: invalid syntax

# %%
df_lim[1:3]
# Out:
#       SEQN   Age  Gender  Body_weight   BMI  HbA1c  Glucose    Height
# 4  73561.0  73.0     2.0         52.0  19.7    4.9    5.940  1.624683
# 7  73564.0  61.0     2.0         93.4  35.7    5.5    6.106  1.617482

# %%
df_lim[1:3:6]
# Out:
#       SEQN   Age  Gender  Body_weight   BMI  HbA1c  Glucose    Height
# 4  73561.0  73.0     2.0         52.0  19.7    4.9     5.94  1.624683

# %%
test = df_lim.loc[:,['Body_weight','Glucose']]

# %%
test[::3]
# Out:
#        Body_weight  Glucose
# 2             88.9   10.713
# 11            47.1    4.940
# 23            93.5    5.718
# 41            86.7    6.106
# 53            90.2    4.996
# 64            76.4    5.551
# 82            81.5    7.383
# 90            74.2    6.162
# 102          117.2    7.716
# 110           88.2    5.495
# 117           58.4    4.940
# 131           97.1    5.829
# 140           57.9    4.885
# 149           91.9   10.214
# 161           99.8    5.273
# 173           89.1    5.829
# 190           78.4   11.324
# 200          102.7    4.885
# 215           68.1    4.996
# 224           80.1    5.718
# 244           63.5    4.607
# 250           69.5    5.940
# 259           82.2    7.161
# 282           99.0   11.768
# 291          116.1    6.606
# 305           98.2    7.605
# 327           92.0    5.940
# 359           82.8    5.829
# 369           88.4    5.773
# 374           68.9    5.162
# ...            ...      ...
# 9803          63.1    5.329
# ...

# %%
#ここからNumpyの問題に入る。
#1.Create an array called bw of “Body_weight” and gen of “Gender” from df_lim.

bw = df_lim['Body_weight']
bw = bw.as_matrix()

gen = df_lim['Gender']
gen = gen.as_matrix()

# %%
#Create an array called age of “Age” from df_lim and 3-array called ‘demo’ with bw and gen in #1.

Age = df_lim['Age']
Age = Age.as_matrix()

demo = np.c_[Age,bw,gen]

# %%
demo
# Out:
# array([[72. , 88.9,  1. ],
#        [73. , 52. ,  2. ],
#        [61. , 93.4,  2. ],
#        ...,
#        [60. , 74.7,  2. ],
#        [61. , 99.5,  1. ],
#        [26. , 71.8,  1. ]])

# %%
#Show the shape of #2.
demo
# Out:
# array([[72. , 88.9,  1. ],
#        [73. , 52. ,  2. ],
#        [61. , 93.4,  2. ],
#        ...,
#        [60. , 74.7,  2. ],
#        [61. , 99.5,  1. ],
#        [26. , 71.8,  1. ]])

# %%
#Convert demo into a dataframe called df_demo with the same column name as those 
#of original arrays and place index in the form of 'Row_i' where i starts from 1.

df_demo = pd.DataFrame(demo)

# %%
df_demo = df_demo.reset_index()

# %%
df_demo
# Out:
#       index     0      1    2
# 0         0  72.0   88.9  1.0
# 1         1  73.0   52.0  2.0
# 2         2  61.0   93.4  2.0
# 3         3  26.0   47.1  2.0
# 4         4  33.0   56.8  2.0
# 5         5  32.0   79.7  1.0
# 6         6  38.0   93.5  2.0
# 7         7  50.0   80.9  1.0
# 8         8  57.0  104.0  2.0
# 9         9  20.0   86.7  1.0
# 10       10  37.0  126.2  1.0
# 11       11  75.0  111.9  1.0
# 12       12  43.0   90.2  1.0
# 13       13  54.0   79.4  2.0
# 14       14  36.0   81.7  2.0
# 15       15  80.0   76.4  1.0
# 16       16  43.0   76.8  2.0
# 17       17  63.0   60.9  2.0
# 18       18  71.0   81.5  1.0
# 19       19  67.0   54.9  2.0
# 20       20  57.0   95.5  2.0
# 21       21  61.0   74.2  2.0
# 22       22  44.0  113.1  1.0
# 23       23  54.0   88.8  1.0
# 24       24  70.0  117.2  2.0
# 25       25  25.0   63.4  1.0
# 26       26  25.0  124.8  1.0
# 27       27  24.0   88.2  1.0
# 28       28  30.0   83.1  2.0
# 29       29  49.0   58.2  1.0
# ...

# %%
df_demo.index = np.arange(1,len(df_demo)+1)

# %%
df_demo
# Out:
#       index     0      1    2
# 1         0  72.0   88.9  1.0
# 2         1  73.0   52.0  2.0
# 3         2  61.0   93.4  2.0
# 4         3  26.0   47.1  2.0
# 5         4  33.0   56.8  2.0
# 6         5  32.0   79.7  1.0
# 7         6  38.0   93.5  2.0
# 8         7  50.0   80.9  1.0
# 9         8  57.0  104.0  2.0
# 10        9  20.0   86.7  1.0
# 11       10  37.0  126.2  1.0
# 12       11  75.0  111.9  1.0
# 13       12  43.0   90.2  1.0
# 14       13  54.0   79.4  2.0
# 15       14  36.0   81.7  2.0
# 16       15  80.0   76.4  1.0
# 17       16  43.0   76.8  2.0
# 18       17  63.0   60.9  2.0
# 19       18  71.0   81.5  1.0
# 20       19  67.0   54.9  2.0
# 21       20  57.0   95.5  2.0
# 22       21  61.0   74.2  2.0
# 23       22  44.0  113.1  1.0
# 24       23  54.0   88.8  1.0
# 25       24  70.0  117.2  2.0
# 26       25  25.0   63.4  1.0
# 27       26  25.0  124.8  1.0
# 28       27  24.0   88.2  1.0
# 29       28  30.0   83.1  2.0
# 30       29  49.0   58.2  1.0
# ...

# %%
#Give me the number of subjects whose gender is female and weight is less than 50 kg.
#Notice:Gender = 2.0 means the data is female data.

data = df_demo[df[0]==1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-41678018200c> in <module>()
# ...

# %%
t = [(df_demo['2'] ==2.0) & (df_demo['1'] >= 50.0)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-153-84c2d65ac9d4> in <module>()
# ...

# %%
df_demo['2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-148-8791f72ee147> in <module>()
# ----> 1 df_demo['2']
#
# ...

# %%
df_demo[1,1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (1, 1)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-149-388ff92abde7> in <module>()
# ----> 1 df_demo[1,1]
#
# ...

# %%
print (df_demo.columns.values)
# Out:
# ['index' 0 1 2]

# %%
df_demo['2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-152-8791f72ee147> in <module>()
# ----> 1 df_demo['2']
#
# ...

# %%
demo_new = df_demo.rename(columns={'1': 'weight','2':'gender'})
#t = [(df_demo['gender'] ==2.0) & (df_demo['weight'] >= 50.0)]

# %%
print(df_demo['gender'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-159-e81f826fc5d1> in <module>()
# ----> 1 print(df_demo['gender'])
#
# ...

# %%
df_demo['weight']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weight'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-160-9d17d4910217> in <module>()
# ----> 1 df_demo['weight']
#
# ...

# %%
df_demo = pd.DataFrame(df_demo)

# %%
df_demo
# Out:
#       index     0      1    2
# 1         0  72.0   88.9  1.0
# 2         1  73.0   52.0  2.0
# 3         2  61.0   93.4  2.0
# 4         3  26.0   47.1  2.0
# 5         4  33.0   56.8  2.0
# 6         5  32.0   79.7  1.0
# 7         6  38.0   93.5  2.0
# 8         7  50.0   80.9  1.0
# 9         8  57.0  104.0  2.0
# 10        9  20.0   86.7  1.0
# 11       10  37.0  126.2  1.0
# 12       11  75.0  111.9  1.0
# 13       12  43.0   90.2  1.0
# 14       13  54.0   79.4  2.0
# 15       14  36.0   81.7  2.0
# 16       15  80.0   76.4  1.0
# 17       16  43.0   76.8  2.0
# 18       17  63.0   60.9  2.0
# 19       18  71.0   81.5  1.0
# 20       19  67.0   54.9  2.0
# 21       20  57.0   95.5  2.0
# 22       21  61.0   74.2  2.0
# 23       22  44.0  113.1  1.0
# 24       23  54.0   88.8  1.0
# 25       24  70.0  117.2  2.0
# 26       25  25.0   63.4  1.0
# 27       26  25.0  124.8  1.0
# 28       27  24.0   88.2  1.0
# 29       28  30.0   83.1  2.0
# 30       29  49.0   58.2  1.0
# ...

# %%
print(df_demo['1'] > 1.0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-164-87bae84fb779> in <module>()
# ----> 1 print(df_demo['1'] > 1.0)
#
# ...

# %%
df_demo.columns=({'1':'weight','2':'gender'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-171-f17d1b839067> in <module>()
# ----> 1 df_demo.columns=({'1':'weight','2':'gender'})
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    3625         try:
#    3626             object.__getattribute__(self, name)
# -> 3627             return object.__setattr__(self, name, value)
#    3628         except AttributeError:
#    3629             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     557
#     558     def _set_axis(self, axis, labels):
# --> 559         self._data.set_axis(axis, labels)
#     560         self._clear_item_cache()
#     561
#
# ...

# %%
df_demo
# Out:
#       index     0      1    2
# 1         0  72.0   88.9  1.0
# 2         1  73.0   52.0  2.0
# 3         2  61.0   93.4  2.0
# 4         3  26.0   47.1  2.0
# 5         4  33.0   56.8  2.0
# 6         5  32.0   79.7  1.0
# 7         6  38.0   93.5  2.0
# 8         7  50.0   80.9  1.0
# 9         8  57.0  104.0  2.0
# 10        9  20.0   86.7  1.0
# 11       10  37.0  126.2  1.0
# 12       11  75.0  111.9  1.0
# 13       12  43.0   90.2  1.0
# 14       13  54.0   79.4  2.0
# 15       14  36.0   81.7  2.0
# 16       15  80.0   76.4  1.0
# 17       16  43.0   76.8  2.0
# 18       17  63.0   60.9  2.0
# 19       18  71.0   81.5  1.0
# 20       19  67.0   54.9  2.0
# 21       20  57.0   95.5  2.0
# 22       21  61.0   74.2  2.0
# 23       22  44.0  113.1  1.0
# 24       23  54.0   88.8  1.0
# 25       24  70.0  117.2  2.0
# 26       25  25.0   63.4  1.0
# 27       26  25.0  124.8  1.0
# 28       27  24.0   88.2  1.0
# 29       28  30.0   83.1  2.0
# 30       29  49.0   58.2  1.0
# ...

# %%
df_demo
# Out:
#       index     0      1    2
# 1         0  72.0   88.9  1.0
# 2         1  73.0   52.0  2.0
# 3         2  61.0   93.4  2.0
# 4         3  26.0   47.1  2.0
# 5         4  33.0   56.8  2.0
# 6         5  32.0   79.7  1.0
# 7         6  38.0   93.5  2.0
# 8         7  50.0   80.9  1.0
# 9         8  57.0  104.0  2.0
# 10        9  20.0   86.7  1.0
# 11       10  37.0  126.2  1.0
# 12       11  75.0  111.9  1.0
# 13       12  43.0   90.2  1.0
# 14       13  54.0   79.4  2.0
# 15       14  36.0   81.7  2.0
# 16       15  80.0   76.4  1.0
# 17       16  43.0   76.8  2.0
# 18       17  63.0   60.9  2.0
# 19       18  71.0   81.5  1.0
# 20       19  67.0   54.9  2.0
# 21       20  57.0   95.5  2.0
# 22       21  61.0   74.2  2.0
# 23       22  44.0  113.1  1.0
# 24       23  54.0   88.8  1.0
# 25       24  70.0  117.2  2.0
# 26       25  25.0   63.4  1.0
# 27       26  25.0  124.8  1.0
# 28       27  24.0   88.2  1.0
# 29       28  30.0   83.1  2.0
# 30       29  49.0   58.2  1.0
# ...

# %%
data = df_demo.rename(columns={'1' : 'weight','2':'gender'}, inplace=True)

# %%
data

# %%
df_demo[(df_demo[2]==2.0) & (df_demo[1]>50.0)]
# Out:
#       index     0      1    2
# 2         1  73.0   52.0  2.0
# 3         2  61.0   93.4  2.0
# 5         4  33.0   56.8  2.0
# 7         6  38.0   93.5  2.0
# 9         8  57.0  104.0  2.0
# 14       13  54.0   79.4  2.0
# 15       14  36.0   81.7  2.0
# 17       16  43.0   76.8  2.0
# 18       17  63.0   60.9  2.0
# 20       19  67.0   54.9  2.0
# 21       20  57.0   95.5  2.0
# 22       21  61.0   74.2  2.0
# 25       24  70.0  117.2  2.0
# 29       28  30.0   83.1  2.0
# 31       30  45.0   58.4  2.0
# 33       32  61.0  105.2  2.0
# 35       34  77.0   56.3  2.0
# 36       35  66.0   76.0  2.0
# 37       36  57.0   57.9  2.0
# 39       38  48.0  123.3  2.0
# 42       41  29.0   71.9  2.0
# 48       47  46.0   73.7  2.0
# 49       48  80.0   78.4  2.0
# 52       51  29.0  102.7  2.0
# 53       52  31.0  102.8  2.0
# 54       53  35.0   53.0  2.0
# 55       54  21.0   68.1  2.0
# 56       55  39.0   67.0  2.0
# 58       57  48.0   80.1  2.0
# 61       60  46.0   63.5  2.0
# ...

# %%
#Visualization
conda install bokeh
# Out:
#   File "<ipython-input-189-617845b09ab5>", line 2
#     conda install bokeh
#                 ^
# SyntaxError: invalid syntax

# %%
from bokeh.plotting import figure, output_file, show

# %%
df3
# Out:
#           SEQN   Age  Gender  Body_weight   BMI  HbA1c  Glucose    Height
# 2      73559.0  72.0     1.0         88.9  28.9    8.9   10.713  1.753888
# 4      73561.0  73.0     2.0         52.0  19.7    4.9    5.940  1.624683
# 7      73564.0  61.0     2.0         93.4  35.7    5.5    6.106  1.617482
# 11     73568.0  26.0     2.0         47.1  20.3    5.2    4.940  1.523219
# 17     73574.0  33.0     2.0         56.8  22.8    5.0    4.663  1.578362
# 19     73576.0  16.0     1.0         67.3  23.2    5.1    4.940  1.703192
# 20     73577.0  32.0     1.0         79.7  28.9    5.3    5.773  1.660658
# 23     73580.0  38.0     2.0         93.5  35.9    5.8    5.718  1.613833
# 24     73581.0  50.0     1.0         80.9  23.6    5.0    6.106  1.851477
# 30     73587.0  14.0     1.0        110.2  38.7    5.7    5.218  1.687467
# 39     73596.0  57.0     2.0        104.0  38.3    5.9    5.940  1.647849
# 41     73598.0  20.0     1.0         86.7  31.8    5.2    6.106  1.651186
# ...

# %%
graph_data1 = df3[(df3['Gender']==1.0)]

# %%
x = graph_data1['Age']

# %%
y = graph_data1['HbA1c']

# %%
p = figure(title="HbA1c - Male", x_axis_label='Age', y_axis_label='HbA1c')

# %%
p.line(x, y, legend="Temp.", line_width=2)
# Out:
# GlyphRenderer(id='ed4988e1-8e5c-4f78-821a-aa794ff82b3d', ...)

# %%
show(p)

# %%
output_file("Vis1.html")

# %%
p = figure(plot_width=400, plot_height=400)

# %%
show(p)
# Out:
# W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure(id='b46878db-3455-4b09-b768-b3032a25dcd8', ...)

# %%
p.circle(x, y, size=5, color="navy", alpha=0.5)
# Out:
# GlyphRenderer(id='85223428-6a3d-4981-ae21-0023be6ba7c0', ...)

# %%
show(p)
