# %%
# coding: utf-8
import numpy as np
import pandas as pd

str = "stressed"
#スライス
print(str[::-1])
# Out:
# desserts

# %%
str2="パタトクカシー"
str2[::2]
# Out:
# 'パトカー'

# %%
str3="パトカー"
str4="タクシー"
str5=""
for i in range(0,4):
  str = (str3 + str4)[i::4]
  str5 += str
str5
"".join([s1+s2 for (s1,s2) in zip("パトカー","タクシー")])
# Out:
# 'パタトクカシーー'

# %%
str6 = "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."
str6
# Out:
# 'Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics.'

# %%
words = str6.split(" ")
strlength = []#np.empty(len(words))
#for i in range(0,len(words)-1):
#    strlength.append(len(words[i]))
#for文の内包表記
strlength = [len(words[i]) for i in range(0, len(words)-1)]
strlength
# Out:
# [3, 1, 4, 1, 6, 9, 2, 7, 5, 3, 5, 8, 9, 7]

# %%
str7 = "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."
wordsstr7 = str7.split(" ")
dict = {}
for i in range(0, len(wordsstr7)-1):
    w = i+1
    if w in [1, 5, 6, 7, 8, 9, 15, 16, 19]:
        dict[i] = {wordsstr7[i][0]:1}
    else:
        dict[i] = {wordsstr7[i][1]:2}
dict
#先頭の1文字(または2文字)と、その単語のインデックスを対応付ける辞書を作成
link = {w[:2-(i in (1,5,6,7,8,9,15,16,19))]:i for i,w in enumerate(str7.split(),1)}
print(link)
# Out:
# {'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'Ne': 10, 'Na': 11, 'Mi': 12, 'Al': 13, 'Si': 14, 'P': 15, 'S': 16, 'Cl': 17, 'Ar': 18, 'K': 19, 'Ca': 20}

# %%
#Q5
str8="I am an NLPer"

# %%
def process_MeCab(mecab_filename):

    with open(mecab_filename, encoding='utf-8') as mecab_file:
        sentense = []
        sentenses = []

        for morpheme in mecab_file.read().split('\n'):
            # 　→　表層形\t品詞,品詞細分類1,品詞細分類2,品詞細分類3,活用型,活用形,原形,読み,発音
            surfase = morpheme.split('\t')
            if len(surfase) >= 2:            # EOS対象外
                # カンマで区切る
                result = surfase[1].split(',')
                # 結果を格納
                word = {
                    'surface' : surfase[0],
                    'base' : result[6],
                    'pos' : result[0],
                    'pos1' : result[1]
                }
                # 文単位に追加
                sentense.append(word)
                # 句点から終了
                if word['pos1'] == '句点':
                    sentenses.append(sentense)
                    sentense = []

    return sentenses

# %%
sentences = process_MeCab('nekoresult.txt')

# %%
#Q11
for j in range(len(sentences)):
    print([sentences[j][i]['surface'] for i in range(len(sentences[j])) if sentences[j][i]['pos']=='動詞'])
# Out:
# []
# []
# ['生れ', 'つか']
# ['し', '泣い', 'し', 'いる']
# ['始め', '見']
# ['聞く']
# ['捕え', '煮', '食う']
# ['思わ']
# ['載せ', 'られ', '持ち上げ', 'られ', 'し', 'あっ']
# ['落ちつい', '見', '見']
# ['思っ', '残っ', 'いる']
# ['さ', 'れ', 'し']
# ['逢っ', '出会わ', 'し']
# ['のみ', 'なら', 'し', 'いる']
# ['吹く']
# ['せ', '弱っ']
# ['飲む', '知っ']
# ['坐っ', 'おっ', 'する', 'し', '始め']
# ['動く', '動く', '分ら', '廻る']
# ['なる']
# ['助から', '思っ', 'いる', 'さり', 'し', '出']
# ['し', 'いる', '考え出そ', '分ら']
# ['付い', '見る', 'い']
# ['おっ', '見え']
# ['隠し', 'しまっ']
# ['違っ']
# ['明い', 'い', 'られ']
# ['這い出し', '見る']
# ['棄て', 'られ']
# ['這い出す', 'ある']
# ['坐っ', 'し', '考え', '見']
# ['出']
# ['し', '泣い', '来', 'くれる', '考え付い']
# ['やっ', '見', '来']
# ['渡っ', 'かかる']
# ['減っ', '来']
# ['泣き', '出']
# ['ある', 'ある', 'し', 'そろ', '廻り', '始め']
# []
# ['し', '這っ', '行く', '出']
# ['這入っ', 'なる', '思っ', '崩れ', 'もぐり込ん']
# ['破れ', 'い', 'し', '知れ']
# ['云っ']
# ['至る', 'する', 'なっ', 'いる']
# ['忍び込ん', '分ら']
# ['なる', '減る', '降っ', '来る', '出来', 'なっ']
# ['あるい', '行く']
# ['考える', '這入っ', 'おっ']
# ['見る', 'し']
# ['逢っ']
# ['見る', 'つかん', '抛り出し']
# ...

# %%
#Q12
for j in range(len(sentences)):
    print([sentences[j][i]['base'] for i in range(len(sentences[j])) if sentences[j][i]['pos']=='動詞'])
# Out:
# []
# []
# ['生れる', 'つく']
# ['する', '泣く', 'する', 'いる']
# ['始める', '見る']
# ['聞く']
# ['捕える', '煮る', '食う']
# ['思う']
# ['載せる', 'られる', '持ち上げる', 'られる', 'する', 'ある']
# ['落ちつく', '見る', '見る']
# ['思う', '残る', 'いる']
# ['する', 'れる', 'する']
# ['逢う', '出会う', 'する']
# ['のむ', 'なる', 'する', 'いる']
# ['吹く']
# ['する', '弱る']
# ['飲む', '知る']
# ['坐る', 'おる', 'する', 'する', '始める']
# ['動く', '動く', '分る', '廻る']
# ['なる']
# ['助かる', '思う', 'いる', 'さる', 'する', '出る']
# ['する', 'いる', '考え出す', '分る']
# ['付く', '見る', 'いる']
# ['おる', '見える']
# ['隠す', 'しまう']
# ['違う']
# ['明く', 'いる', 'られる']
# ['這い出す', '見る']
# ['棄てる', 'られる']
# ['這い出す', 'ある']
# ['坐る', 'する', '考える', '見る']
# ['出る']
# ['する', '泣く', '来る', 'くれる', '考え付く']
# ['やる', '見る', '来る']
# ['渡る', 'かかる']
# ['減る', '来る']
# ['泣く', '出る']
# ['ある', 'ある', 'する', 'そる', '廻る', '始める']
# []
# ['する', '這う', '行く', '出る']
# ['這入る', 'なる', '思う', '崩れる', 'もぐり込む']
# ['破れる', 'いる', 'する', '知れる']
# ['云う']
# ['至る', 'する', 'なる', 'いる']
# ['忍び込む', '分る']
# ['なる', '減る', '降る', '来る', '出来る', 'なる']
# ['あるく', '行く']
# ['考える', '這入る', 'おる']
# ...

# %%
#Q13
for j in range(len(sentences)):
    print([sentences[j][i]['base'] for i in range(len(sentences[j])) if sentences[j][i]['pos1']=='サ変接続'])
# Out:
# []
# []
# ['見当']
# ['記憶']
# []
# []
# ['話']
# []
# []
# []
# []
# ['装飾']
# []
# ['突起']
# []
# []
# []
# ['運転']
# []
# []
# []
# ['記憶']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['分別']
# []
# []
# []
# []
# []
# ['決心']
# []
# ['我慢']
# []
# ['餓死']
# []
# ['訪問']
# []
# ['始末', '猶予']
# []
# []
# ['遭遇']
# []
# []
# []
# ['我慢']
# []
# []
# ['記憶']
# []
# ['返報']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['勉強']
# ['勉強']
# []
# ['昼寝']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['珍重']
# []
# []
# ['昼寝']
# []
# ['経験']
# ['供']
# ['供']
# ['供']
# ['供', '*', '*']
# []
# []
# ['同居', '観察', '断言']
# ['同衾', '供']
# []
# ['迫害']
# []
# []
# ['尊敬']
# []
# []
# ['生活', '剿滅']
# ['議論']
# ['所有', '憤慨']
# []
# []
# ['観念', '御馳走', '掠奪']
# []
# ['代言']
# []
# []
# []
# []
# ['我儘', '我儘', '失敗', '話']
# []
# ['投書']
# []
# ['関']
# []
# []
# ['決心']
# ['昼寝']
# ['鑑定']
# ['話']
# []
# ['述懐']
# []
# ['想像']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['写生']
# []
# []
# ['感心']
# []
# ...
